# %% [markdown]
# <a href="https://colab.research.google.com/github/Limteckping45/COS30019Assignment2/blob/main/CNN_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
import plotly.figure_factory as ff
import numpy as np

# Clone the repository
# !git clone "https://github.com/Limteckping45/COS30019Assignment2"
cnn_model = "/content/COS30019Assignment2/CNN_Model.h5"

# Directory paths for the testing dataset
test_data_dir = "/content/COS30019Assignment2/testing_dataset"

# Load the trained model
model = load_model(cnn_model)

# Define image dimensions
img_width, img_height = 64, 64
input_shape = (img_width, img_height, 3)
batch_size = 32

# Set up data generator for testing
test_datagen = ImageDataGenerator(rescale=1. / 255)

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False  # No need to shuffle for evaluation
)

# Extract class names from the test generator
class_names = list(test_generator.class_indices.keys())

# Evaluate the model on the testing dataset
evaluation = model.evaluate(test_generator)

# Extract metrics names and values
metrics_names = model.metrics_names
metrics_values = evaluation

# Display evaluation results
print("Evaluation Results:")
for metric, value in zip(metrics_names, metrics_values):
    print(f"{metric}: {value}")

# Predict class labels for the testing dataset
predictions = model.predict(test_generator)
predicted_labels = np.argmax(predictions, axis=1)

# True labels
true_labels = test_generator.classes

# Generate class labels
class_labels = list(test_generator.class_indices.keys())

# Calculate confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix using plotly
fig = ff.create_annotated_heatmap(
    z=conf_matrix,
    x=class_labels,
    y=class_labels,
    colorscale='Blues',
    showscale=True,
    hoverinfo="z",
    xgap=2, ygap=2
)

fig.update_layout(
    title='Confusion Matrix',
    xaxis=dict(title='Predicted Labels'),
    yaxis=dict(title='True Labels')
)

fig.show()
# Out:
# fatal: destination path 'COS30019Assignment2' already exists and is not an empty directory.
# Found 1200 images belonging to 12 classes.
# 38/38 [==============================] - 15s 371ms/step - loss: 1.5616 - accuracy: 0.5633
# Evaluation Results:
# loss: 1.561574935913086
# accuracy: 0.5633333325386047
# 38/38 [==============================] - 15s 363ms/step
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c079f78d-3aaf-40c6-9d8e-19305760ea2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c079f78d-3aaf-40c6-9d8e-19305760ea2e")) {                    Plotly.newPlot(                        "c079f78d-3aaf-40c6-9d8e-19305760ea2e",                        [{"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"hoverinfo":"z","reversescale":false,"showscale":true,"x":["Bengal","Boxer","Chihuahua","Havanese","Japanese Chin","Maine Coon","Persian","Pug","Ragdoll","Russian Blue","Saint Bernard","Siamese"],"xgap":2,"y":["Bengal","Boxer","Chihuahua","Havanese","Japanese Chin","Maine Coon","Persian","Pug","Ragdoll","Russian Blue","Saint Bernard","Siamese"],"ygap":2,"z":[[33,18,5,3,0,27,2,9,0,2,1,0],[3,60,3,3,4,1,1,10,0,0,14,1],[0,12,65,1,1,2,0,3,1,4,10,1],[2,3,2,61,3,6,6,3,0,1,13,0],[0,2,2,6,76,4,0,2,2,0,6,0],[7,12,1,5,1,50,10,9,0,4,0,1],[2,2,6,6,2,18,30,0,9,20,5,0],[0,4,0,3,0,2,0,84,0,4,3,0],[0,3,3,18,3,4,15,6,31,2,4,11],[1,6,0,1,0,17,2,2,0,71,0,0],[0,18,0,0,5,0,0,2,0,0,75,0],[0,8,9,5,0,2,4,15,6,6,5,40]],"type":"heatmap"}],                        {"annotations":[{"font":{"color":"#000000"},"showarrow":false,"text":"33","x":"Bengal","xref":"x","y":"Bengal","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"18","x":"Boxer","xref":"x","y":"Bengal","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"5","x":"Chihuahua","xref":"x","y":"Bengal","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"3","x":"Havanese","xref":"x","y":"Bengal","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0","x":"Japanese Chin","xref":"x","y":"Bengal","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"27","x":"Maine Coon","xref":"x","y":"Bengal","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"2","x":"Persian","xref":"x","y":"Bengal","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"9","x":"Pug","xref":"x","y":"Bengal","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0","x":"Ragdoll","xref":"x","y":"Bengal","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"2","x":"Russian Blue","xref":"x","y":"Bengal","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"1","x":"Saint Bernard","xref":"x","y":"Bengal","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0","x":"Siamese","xref":"x","y":"Bengal","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"3","x":"Bengal","xref":"x","y":"Boxer","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"60","x":"Boxer","xref":"x","y":"Boxer","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"3","x":"Chihuahua","xref":"x","y":"Boxer","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"3","x":"Havanese","xref":"x","y":"Boxer","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"4","x":"Japanese Chin","xref":"x","y":"Boxer","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"1","x":"Maine Coon","xref":"x","y":"Boxer","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"1","x":"Persian","xref":"x","y":"Boxer","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"10","x":"Pug","xref":"x","y":"Boxer","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0","x":"Ragdoll","xref":"x","y":"Boxer","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"0","x":"Russian Blue","xref":"x","y":"Boxer","yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"14 ...

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Clone the repository
# !git clone "https://github.com/Limteckping45/COS30019Assignment2"
cnn_model = "/content/COS30019Assignment2/CNN_Model.h5"

# Directory paths for the testing dataset
test_data_dir = "/content/COS30019Assignment2/testing_dataset"

# Load the trained model
model = load_model(cnn_model)

# Define image dimensions
img_width, img_height = 64, 64
input_shape = (img_width, img_height, 3)
batch_size = 32

# Set up data generator for testing
test_datagen = ImageDataGenerator(rescale=1. / 255)

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False  # No need to shuffle for evaluation
)

# Predict class labels for the testing dataset
predictions = model.predict(test_generator)
predicted_labels = np.argmax(predictions, axis=1)

# True labels
true_labels = test_generator.classes

# Generate class labels
class_labels = list(test_generator.class_indices.keys())

# Generate classification report
report = classification_report(true_labels, predicted_labels, target_names=class_labels, output_dict=True)

# Convert the classification report to a DataFrame
report_df = pd.DataFrame(report).transpose()

# Remove support column for visualization
report_df = report_df.drop(columns=['support'])

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(report_df.iloc[:-1, :].T, annot=True, cmap="coolwarm", cbar=True)
plt.title("Classification Report")
plt.xlabel("Metrics")
plt.ylabel("Classes")
plt.show()
# Out:
# Cloning into 'COS30019Assignment2'...
# remote: Enumerating objects: 3589, done.
# remote: Counting objects: 100% (1195/1195), done.
# remote: Compressing objects: 100% (1161/1161), done.
# remote: Total 3589 (delta 34), reused 1195 (delta 34), pack-reused 2394
# Receiving objects: 100% (3589/3589), 408.73 MiB | 21.54 MiB/s, done.
# Resolving deltas: 100% (52/52), done.
# Updating files: 100% (3281/3281), done.
# Found 1200 images belonging to 12 classes.
# 38/38 [==============================] - 16s 335ms/step
